# %%
import pandas as pd
df_movie =  pd.read_csv(r"C:\Users\Giova\OneDrive\Escritorio\HENRY\Henry Practice\1 proyecto Individual\src\df_movie.csv")
df_crew = pd.read_csv(r"C:\Users\Giova\OneDrive\Escritorio\HENRY\Henry Practice\1 proyecto Individual\src\df_crew.csv")
df_cast =pd.read_csv(r"C:\Users\Giova\OneDrive\Escritorio\HENRY\Henry Practice\1 proyecto Individual\src\df_cast.csv")

# %%
csv_file_path = ("./data/df_movie.csv")
csv_file_path3 = ("./data/df_crew.csv")
csv_file_path2 = ("./data/df_cast.csv")
# Carga el archivo CSV en un DataFrame de Pandas
try:
    df_movie = pd.read_csv("./data/df_movie.csv")
    df_cast = pd.read_csv("./data/df_cast.csv")
    df_crew = pd.read_csv("./data/df_crew.csv")
# Out:
#             id                  crewjob             crewname
# 0          862                 Director        John Lasseter
# 1          862               Screenplay          Joss Whedon
# 2          862               Screenplay       Andrew Stanton
# 3          862               Screenplay           Joel Cohen
# 4          862               Screenplay         Alec Sokolow
# ...        ...                      ...                  ...
# 463831   67758  Original Music Composer       Richard McHugh
# 463832   67758  Director of Photography       João Fernandes
# 463833  227506                 Director     Yakov Protazanov
# 463834  227506                 Producer  Joseph N. Ermolieff
# 463835  461257                 Director        Daisy Asquith
#
# [463836 rows x 3 columns]

# %%
df_combined = pd.merge(df_movie, df_cast, on='id', how='left')

# %%
df_combined
# Out:
#             budget      id original_language  \
# 0       30000000.0     862                en
# 1       30000000.0     862                en
# 2       30000000.0     862                en
# 3       30000000.0     862                en
# 4       30000000.0     862                en
# ...            ...     ...               ...
# 564253         0.0  227506                en
# 564254         0.0  227506                en
# 564255         0.0  227506                en
# 564256         0.0  227506                en
# 564257         0.0  461257                en
#
#                                                  overview  popularity  \
# 0       Led by Woody, Andy's toys live happily in his ...   21.946943
# 1       Led by Woody, Andy's toys live happily in his ...   21.946943
# 2       Led by Woody, Andy's toys live happily in his ...   21.946943
# 3       Led by Woody, Andy's toys live happily in his ...   21.946943
# 4       Led by Woody, Andy's toys live happily in his ...   21.946943
# ...                                                   ...         ...
# 564253  In a small town live two brothers, one a minis...    0.003503
# 564254  In a small town live two brothers, one a minis...    0.003503
# 564255  In a small town live two brothers, one a minis...    0.003503
# 564256  In a small town live two brothers, one a minis...    0.003503
# 564257  50 years after decriminalisation of homosexual...    0.163015
#
#        release_date      revenue  runtime    status tagline  ...  \
# 0        1995-10-30  373554033.0     81.0  Released     NaN  ...
# 1        1995-10-30  373554033.0     81.0  Released     NaN  ...
# 2        1995-10-30  373554033.0     81.0  Released     NaN  ...
# 3        1995-10-30  373554033.0     81.0  Released     NaN  ...
# 4        1995-10-30  373554033.0     81.0  Released     NaN  ...
# ...             ...          ...      ...       ...     ...  ...
# 564253   1917-10-21          0.0     87.0  Released     NaN  ...
# 564254   1917-10-21          0.0     87.0  Released     NaN  ...
# 564255   1917-10-21          0.0     87.0  Released     NaN  ...
# 564256   1917-10-21          0.0     87.0  Released     NaN  ...
# 564257   2017-06-09          0.0     75.0  Released     NaN  ...
#
#        production_companiesid  production_countriesiso_3166_1  \
# 0                         3.0                              US
# 1                         3.0                              US
# 2                         3.0                              US
# 3                         3.0                              US
# 4                         3.0                              US
# ...                       ...                             ...
# 564253                88753.0                              RU
# 564254                88753.0                              RU
# 564255                88753.0                              RU
# 564256                88753.0                              RU
# 564257                    NaN                              GB
#
#         production_countriesname release_year  spoken_languages_names  \
# 0       United States of America         1995                 English
# 1       United States of America         1995                 English
# 2       United States of America         1995                 English
# 3       United States of America         1995                 English
# 4       United States of America         1995                 English
# ...                          ...          ...                     ...
# 564253                    Russia         1917                     NaN
# 564254                    Russia         1917                     NaN
# 564255                    Russia         1917                     NaN
# 564256                    Russia         1917                     NaN
# 564257            United Kingdom         2017                 English
#
#        spoken_languages_iso     genres_ids               genres_names  \
# 0                        en  16, 35, 10751  Family, Animation, Comedy
# 1                        en  16, 35, 10751  Family, Animation, Comedy
# 2                        en  16, 35, 10751  Family, Animation, Comedy
# 3                        en  16, 35, 10751  Family, Animation, Comedy
# 4                        en  16, 35, 10751  Family, Animation, Comedy
# ...                     ...            ...                        ...
# 564253                  NaN            NaN                        NaN
# 564254                  NaN            NaN                        NaN
# 564255                  NaN            NaN                        NaN
# 564256                  NaN            NaN                        NaN
# 564257                   en            NaN                        NaN
#
#            return           castname
# 0       12.451801          Tom Hanks
# 1       12.451801          Tim Allen
# 2       12.451801        Don Rickles
# 3       12.451801         Jim Varney
# 4       12.451801      Wallace Shawn
# ...           ...                ...
# 564253   0.000000  Nathalie Lissenko
# 564254   0.000000       Pavel Pavlov
# 564255   0.000000  Aleksandr Chabrov
# 564256   0.000000        Vera Orlova
# 564257   0.000000                NaN
#
# [564258 rows x 24 columns]
